# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import matplotlib.pyplot as plt
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,random_split,TensorDataset
from torchvision.utils import make_grid
from torchvision.transforms import ToTensor
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import torchvision.models as models

# %%
from tqdm.notebook import tqdm

# %%
project_name = 'project-plant-identification'

# %%
data ='..\\Plant-Dataset\\'
os.listdir(data)
# Out:
# ['New Plant-Dataset']

# %%
os.listdir(data+'New Plant-Dataset')
# Out:
# ['orig', 'train', 'valid']

# %%
os.listdir(data+'New Plant-Dataset\\train')
# Out:
# ['Augmented Arjun Leaf',
#  'Augmented Curry Leaf',
#  'Augmented Marsh Pennywort Leaf',
#  'Augmented Mint Leaf',
#  'Augmented Neem Leaf',
#  'Augmented Rubble Leaf']

# %%
unique_plants = []
cl = os.listdir(data+'New Plant-Dataset\\train')
for i in cl:
    x = i.split('_')
    if x[0] not in unique_plants:
        unique_plants.append(x[0])
print("Number of Unique Plants: ",len(unique_plants))
print("Unique Plants: ",unique_plants)
# Out:
# Number of Unique Plants:  6
# Unique Plants:  ['Augmented Arjun Leaf', 'Augmented Curry Leaf', 'Augmented Marsh Pennywort Leaf', 'Augmented Mint Leaf', 'Augmented Neem Leaf', 'Augmented Rubble Leaf']

# %%
from torchvision import transforms

# Define desired height and width
desired_height = 128
desired_width = 128

# Define transformation
transform = transforms.Compose([
    transforms.Resize((desired_height, desired_width)),
    transforms.ToTensor()
])

# %%
dataset = ImageFolder(data+'New Plant-Dataset\\train',transform=transform)
test_ds = ImageFolder(data+'New Plant-Dataset\\orig',transform=transform)

# %%
print("Number of training images: ",len(dataset))
print("Number of testing images: ",len(test_ds))
# Out:
# Number of training images:  9661
# Number of testing images:  1381

# %%
num_classes = dataset.classes
print("Number of classes: ",len(num_classes))
print(num_classes)
# Out:
# Number of classes:  6
# ['Augmented Arjun Leaf', 'Augmented Curry Leaf', 'Augmented Marsh Pennywort Leaf', 'Augmented Mint Leaf', 'Augmented Neem Leaf', 'Augmented Rubble Leaf']

# %%
image, label  = dataset[0]
print("Image shape:",image.shape)
print("Image Label: ",label)
print("Image Label: ",dataset.classes[label])
print(image)
# Out:
# Image shape: torch.Size([3, 128, 128])
# Image Label:  0
# Image Label:  Augmented Arjun Leaf
# tensor([[[0.9098, 0.9020, 0.9098,  ..., 0.9961, 0.9961, 0.9961],
#          [0.9059, 0.9059, 0.9098,  ..., 0.9961, 0.9961, 0.9961],
#          [0.8941, 0.8980, 0.9020,  ..., 0.9961, 0.9961, 0.9961],
#          ...,
#          [0.8314, 0.8392, 0.8353,  ..., 0.9765, 0.9765, 0.9725],
#          [0.8314, 0.8392, 0.8353,  ..., 0.9725, 0.9804, 0.9765],
#          [0.8353, 0.8353, 0.8314,  ..., 0.9725, 0.9725, 0.9725]],
#
#         [[0.8980, 0.8902, 0.8980,  ..., 1.0000, 1.0000, 1.0000],
#          [0.8941, 0.8941, 0.8980,  ..., 1.0000, 1.0000, 1.0000],
#          [0.8824, 0.8863, 0.8902,  ..., 1.0000, 1.0000, 1.0000],
#          ...,
#          [0.8196, 0.8275, 0.8235,  ..., 0.9647, 0.9647, 0.9608],
#          [0.8196, 0.8275, 0.8235,  ..., 0.9608, 0.9686, 0.9647],
#          [0.8235, 0.8235, 0.8196,  ..., 0.9608, 0.9608, 0.9608]],
#
#         [[0.8706, 0.8627, 0.8706,  ..., 0.9765, 0.9765, 0.9765],
#          [0.8667, 0.8667, 0.8706,  ..., 0.9765, 0.9765, 0.9765],
#          [0.8549, 0.8588, 0.8627,  ..., 0.9765, 0.9765, 0.9765],
#          ...,
#          [0.7922, 0.8000, 0.7961,  ..., 0.9451, 0.9451, 0.9412],
#          [0.7922, 0.8000, 0.7961,  ..., 0.9412, 0.9490, 0.9451],
#          [0.7961, 0.7961, 0.7922,  ..., 0.9412, 0.9412, 0.9412]]])

# %%
image, label  = dataset[0]
fig,(ax1,ax2) = plt.subplots(figsize=(15,5),nrows=1,ncols=2)
ax1.imshow(image.permute(1,2,0))
ax1.set_title("original image")
ax2.imshow(1-image.permute(1,2,0))
ax2.set_title("inverted image")
plt.show()

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %%
validation_split = 0.3
val_size = int(len(dataset) * validation_split)
train_size = len(dataset) - val_size

train_ds,val_ds = random_split(dataset,[train_size,val_size])

# %%
batch_size = 64

train_loader = DataLoader(train_ds,batch_size=batch_size,num_workers=2,shuffle=True, pin_memory=True)
val_loader = DataLoader(val_ds,batch_size=batch_size,num_workers=2,shuffle=True, pin_memory=True)
test_loader = DataLoader(test_ds,batch_size=batch_size,num_workers=2,shuffle=True, pin_memory=True)

# %%
for images, labels in train_loader:
    fig, ax = plt.subplots(figsize=(20, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
    break

# %%
def accuracy(outputs, labels):
  _, preds = torch.max(outputs, dim=1)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    
  def training_step(self,batch):
    images,labels = batch
    out = self(images)
    loss = F.cross_entropy(out,labels)
    return loss

  def validation_step(self,batch):
    images,labels = batch
    out = self(images)
    loss = F.cross_entropy(out,labels)
    acc = accuracy(out,labels)
    return {'val_loss':loss,'val_acc':acc}

  def validation_epoch_end(self,outputs):
    batch_loss = [out['val_loss'] for out in outputs]
    epoch_loss = torch.stack(batch_loss).mean()
    batch_acc = [out['val_acc'] for out in outputs]
    epoch_acc = torch.stack(batch_acc).mean()
    return {'val_loss':epoch_loss.item(),'val_acc':epoch_acc.item()}

  def epoch_end(self,epoch,result):
    print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class Herbal_Identification_Model(ImageClassificationBase):
  
  def __init__(self):
    super().__init__()
    self.network = nn.Sequential(
        nn.Conv2d(3,32,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.Conv2d(32,64,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2), #output : 64*64*64

        nn.Conv2d(64,64,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.Conv2d(64,128,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2), #output : 128*32*32

        nn.Conv2d(128,128,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.Conv2d(128,256,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2), #output : 256*16*16
        
        nn.Conv2d(256,256,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.Conv2d(256,512,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2), #output : 512*8*8
        
        nn.Conv2d(512,512,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.Conv2d(512,1024,kernel_size=3,stride=1,padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2), #output : 1024*4*4
        nn.AdaptiveAvgPool2d(1),
        
        nn.Flatten(),
        nn.Linear(1024,512),
        nn.ReLU(),
        nn.Linear(512,256),
        nn.ReLU(),
        nn.Linear(256,38)
        )
    
  def forward(self,xb):
    out = self.network(xb)
    return out

# %%
class Herbal_Identification_Model1(ImageClassificationBase):
  
  def __init__(self):
    super().__init__()
    self.network = models.vgg16(pretrained=True)
    num_ftrs = self.network.classifier[-1].in_features
    self.network.classifier[-1] = nn.Linear(num_ftrs, 38)
    
  def forward(self,xb):
    out = self.network(xb)
    return out

# %%
class Herbal_Identification_Model2(ImageClassificationBase):
  
  def __init__(self):
    super().__init__()
    self.network = models.resnet34(pretrained=True)
    num_ftrs = self.network.fc.in_features
    self.network.fc = nn.Linear(num_ftrs, 38)
    
  def forward(self,xb):
    out = self.network(xb)
    return out

# %%
@torch.no_grad()
def evaluate(model,val_loader):
  model.eval()
  outputs = [model.validation_step(batch) for batch in val_loader]
  return model.validation_epoch_end(outputs)

# %%
def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
  history = []
  optimizer = opt_func(model.parameters(), lr)
  for epoch in range(epochs):
    model.train()
    train_losses = []
    for batch in tqdm(train_loader):
      loss = model.training_step(batch)
      train_losses.append(loss)
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()
    result = evaluate(model, val_loader)
    result['train_loss'] = torch.stack(train_losses).mean().item()
    model.epoch_end(epoch, result)
    history.append(result)
  return history

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %%
model = to_device(Herbal_Identification_Model2(), device)
# Out:
# d:\.R5-3600-Desktop\Documents\Code\ACLC-Butuan\Other\Herbal-Identification\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\.R5-3600-Desktop\Documents\Code\ACLC-Butuan\Other\Herbal-Identification\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model
# Out:
# Herbal_Identification_Model2(
#   (network): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=38, bias=True)
#   )
# )

# %%
evaluate(model,val_loader)
# Out:
# {'val_loss': 4.001966953277588, 'val_acc': 0.02445652149617672}

# %%
history = fit(10, 0.001, model, train_loader, val_loader, opt_func = torch.optim.Adam)
# Out:
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [0], train_loss: 0.1776, val_loss: 0.0379, val_acc: 0.9918
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [1], train_loss: 0.0499, val_loss: 0.0128, val_acc: 0.9966
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [2], train_loss: 0.0325, val_loss: 0.2015, val_acc: 0.9421
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [3], train_loss: 0.0288, val_loss: 0.0881, val_acc: 0.9800
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [4], train_loss: 0.0277, val_loss: 0.0162, val_acc: 0.9986
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [5], train_loss: 0.0123, val_loss: 0.0247, val_acc: 0.9986
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [6], train_loss: 0.0148, val_loss: 0.0294, val_acc: 0.9963
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [7], train_loss: 0.0240, val_loss: 0.0209, val_acc: 0.9983
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [8], train_loss: 0.0009, val_loss: 0.0158, val_acc: 0.9986
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [9], train_loss: 0.0002, val_loss: 0.0150, val_acc: 0.9986

# %%
history += fit(5, 0.001, model, train_loader, val_loader, opt_func = torch.optim.Adam)
# Out:
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [0], train_loss: 0.0437, val_loss: 0.0634, val_acc: 0.9820
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [1], train_loss: 0.0167, val_loss: 3.0462, val_acc: 0.6860
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [2], train_loss: 0.0106, val_loss: 0.0169, val_acc: 0.9993
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [3], train_loss: 0.0434, val_loss: 0.0280, val_acc: 0.9980
#   0%|          | 0/106 [00:00<?, ?it/s]
# Epoch [4], train_loss: 0.0127, val_loss: 0.3980, val_acc: 0.9183

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
plot_accuracies(history)

# %%
plot_losses(history)

# %%
evaluate(model,val_loader)
# Out:
# {'val_loss': 0.3995401859283447, 'val_acc': 0.9174215197563171}

# %%
x = evaluate(model,test_loader)
x
# Out:
# {'val_loss': 7.952911853790283, 'val_acc': 0.6665003299713135}

# %%
def predict_image(img, model):
    xb = to_device(img.unsqueeze(0), device)
    yb = model(xb)
    _, preds  = torch.max(yb, dim=1)
    return dataset.classes[preds[0].item()]

# %%
img, label = test_ds[25]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: Augmented Arjun Leaf , Predicted: Augmented Arjun Leaf

# %%
img, label = test_ds[978]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: Augmented Neem Leaf , Predicted: Augmented Rubble Leaf

# %%
img, label = test_ds[258]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: Augmented Curry Leaf , Predicted: Augmented Curry Leaf

# %%
print(len(test_ds))
# Out:
# 1381

# %%
for i in range(len(test_ds)):
    path, target = test_ds.samples[i]
    print("Sample {}: Path: {}, Target: {}".format(i, path, target))
# Out:
# Sample 0: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (1).JPG, Target: 0
# Sample 1: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (10).JPG, Target: 0
# Sample 2: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (100).JPG, Target: 0
# Sample 3: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (101).JPG, Target: 0
# Sample 4: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (102).JPG, Target: 0
# Sample 5: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (103).JPG, Target: 0
# Sample 6: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (104).JPG, Target: 0
# Sample 7: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (105).JPG, Target: 0
# Sample 8: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (106).JPG, Target: 0
# Sample 9: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (107).JPG, Target: 0
# Sample 10: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (108).JPG, Target: 0
# Sample 11: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (109).JPG, Target: 0
# Sample 12: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (11).JPG, Target: 0
# Sample 13: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (110).JPG, Target: 0
# Sample 14: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (111).JPG, Target: 0
# Sample 15: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (112).JPG, Target: 0
# Sample 16: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (113).JPG, Target: 0
# Sample 17: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (114).JPG, Target: 0
# Sample 18: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (115).JPG, Target: 0
# Sample 19: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (116).JPG, Target: 0
# Sample 20: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (117).JPG, Target: 0
# Sample 21: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (118).JPG, Target: 0
# Sample 22: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (119).JPG, Target: 0
# Sample 23: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (12).JPG, Target: 0
# Sample 24: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (120).JPG, Target: 0
# Sample 25: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (121).JPG, Target: 0
# Sample 26: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (122).JPG, Target: 0
# Sample 27: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (123).JPG, Target: 0
# Sample 28: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (124).JPG, Target: 0
# Sample 29: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (125).JPG, Target: 0
# Sample 30: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (126).JPG, Target: 0
# Sample 31: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (127).JPG, Target: 0
# Sample 32: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (128).JPG, Target: 0
# Sample 33: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (129).JPG, Target: 0
# Sample 34: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (13).JPG, Target: 0
# Sample 35: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (130).JPG, Target: 0
# Sample 36: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (131).JPG, Target: 0
# Sample 37: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (132).JPG, Target: 0
# Sample 38: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (133).JPG, Target: 0
# Sample 39: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (134).JPG, Target: 0
# Sample 40: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (135).JPG, Target: 0
# Sample 41: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (136).JPG, Target: 0
# Sample 42: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (137).JPG, Target: 0
# Sample 43: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (138).JPG, Target: 0
# Sample 44: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (139).JPG, Target: 0
# Sample 45: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (14).JPG, Target: 0
# Sample 46: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (140).JPG, Target: 0
# Sample 47: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (141).JPG, Target: 0
# Sample 48: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (142).JPG, Target: 0
# Sample 49: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (143).JPG, Target: 0
# Sample 50: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (144).JPG, Target: 0
# Sample 51: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (145).JPG, Target: 0
# Sample 52: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (146).JPG, Target: 0
# Sample 53: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (147).JPG, Target: 0
# Sample 54: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (148).JPG, Target: 0
# Sample 55: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (149).JPG, Target: 0
# Sample 56: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (15).JPG, Target: 0
# Sample 57: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (150).JPG, Target: 0
# Sample 58: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (151).JPG, Target: 0
# Sample 59: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (152).JPG, Target: 0
# Sample 60: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (153).JPG, Target: 0
# Sample 61: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (154).JPG, Target: 0
# Sample 62: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (155).JPG, Target: 0
# Sample 63: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (156).JPG, Target: 0
# Sample 64: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (157).JPG, Target: 0
# Sample 65: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (158).JPG, Target: 0
# Sample 66: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (159).JPG, Target: 0
# Sample 67: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (16).JPG, Target: 0
# Sample 68: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (160).JPG, Target: 0
# Sample 69: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (161).JPG, Target: 0
# Sample 70: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (162).JPG, Target: 0
# Sample 71: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (163).JPG, Target: 0
# Sample 72: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (164).JPG, Target: 0
# Sample 73: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (165).JPG, Target: 0
# Sample 74: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (166).JPG, Target: 0
# Sample 75: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (167).JPG, Target: 0
# Sample 76: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (168).JPG, Target: 0
# Sample 77: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (169).JPG, Target: 0
# Sample 78: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (17).JPG, Target: 0
# Sample 79: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (170).JPG, Target: 0
# Sample 80: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (171).JPG, Target: 0
# Sample 81: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (172).JPG, Target: 0
# Sample 82: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (173).JPG, Target: 0
# Sample 83: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (174).JPG, Target: 0
# Sample 84: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (175).JPG, Target: 0
# Sample 85: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (176).JPG, Target: 0
# Sample 86: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (177).JPG, Target: 0
# Sample 87: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (178).JPG, Target: 0
# Sample 88: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (179).JPG, Target: 0
# Sample 89: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (18).JPG, Target: 0
# Sample 90: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (180).JPG, Target: 0
# Sample 91: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (181).JPG, Target: 0
# Sample 92: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (182).JPG, Target: 0
# Sample 93: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (183).JPG, Target: 0
# Sample 94: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (184).JPG, Target: 0
# Sample 95: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (185).JPG, Target: 0
# Sample 96: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (186).JPG, Target: 0
# Sample 97: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (187).JPG, Target: 0
# Sample 98: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (188).JPG, Target: 0
# Sample 99: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (189).JPG, Target: 0
# Sample 100: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (19).JPG, Target: 0
# Sample 101: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (190).JPG, Target: 0
# Sample 102: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (191).JPG, Target: 0
# Sample 103: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (192).JPG, Target: 0
# Sample 104: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (193).JPG, Target: 0
# Sample 105: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (194).JPG, Target: 0
# Sample 106: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (195).JPG, Target: 0
# Sample 107: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (196).JPG, Target: 0
# Sample 108: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (197).JPG, Target: 0
# Sample 109: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (198).JPG, Target: 0
# Sample 110: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (199).JPG, Target: 0
# Sample 111: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (2).JPG, Target: 0
# Sample 112: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (20).JPG, Target: 0
# Sample 113: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (200).JPG, Target: 0
# Sample 114: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (201).JPG, Target: 0
# Sample 115: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (202).JPG, Target: 0
# Sample 116: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (203).JPG, Target: 0
# Sample 117: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (204).JPG, Target: 0
# Sample 118: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (205).JPG, Target: 0
# Sample 119: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (206).JPG, Target: 0
# Sample 120: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (207).JPG, Target: 0
# Sample 121: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (208).JPG, Target: 0
# Sample 122: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (209).JPG, Target: 0
# Sample 123: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (21).JPG, Target: 0
# Sample 124: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (210).JPG, Target: 0
# Sample 125: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (211).JPG, Target: 0
# Sample 126: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (212).JPG, Target: 0
# Sample 127: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (213).JPG, Target: 0
# Sample 128: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (214).JPG, Target: 0
# Sample 129: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (215).JPG, Target: 0
# Sample 130: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (216).JPG, Target: 0
# Sample 131: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (217).JPG, Target: 0
# Sample 132: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (218).JPG, Target: 0
# Sample 133: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (219).JPG, Target: 0
# Sample 134: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (22).JPG, Target: 0
# Sample 135: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (220).JPG, Target: 0
# Sample 136: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (221).JPG, Target: 0
# Sample 137: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (222).JPG, Target: 0
# Sample 138: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (223).JPG, Target: 0
# Sample 139: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (224).JPG, Target: 0
# Sample 140: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (225).JPG, Target: 0
# Sample 141: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (226).JPG, Target: 0
# Sample 142: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (227).JPG, Target: 0
# Sample 143: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (228).JPG, Target: 0
# Sample 144: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (229).JPG, Target: 0
# Sample 145: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (23).JPG, Target: 0
# Sample 146: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (230).JPG, Target: 0
# Sample 147: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (24).JPG, Target: 0
# Sample 148: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (25).JPG, Target: 0
# Sample 149: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (26).JPG, Target: 0
# Sample 150: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (27).JPG, Target: 0
# Sample 151: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (28).JPG, Target: 0
# Sample 152: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (29).JPG, Target: 0
# Sample 153: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (3).JPG, Target: 0
# Sample 154: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (30).JPG, Target: 0
# Sample 155: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (31).JPG, Target: 0
# Sample 156: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (32).JPG, Target: 0
# Sample 157: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (33).JPG, Target: 0
# Sample 158: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (34).JPG, Target: 0
# Sample 159: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (35).JPG, Target: 0
# Sample 160: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (36).JPG, Target: 0
# Sample 161: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (37).JPG, Target: 0
# Sample 162: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (38).JPG, Target: 0
# Sample 163: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (39).JPG, Target: 0
# Sample 164: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (4).JPG, Target: 0
# Sample 165: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (40).JPG, Target: 0
# Sample 166: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (41).JPG, Target: 0
# Sample 167: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (42).JPG, Target: 0
# Sample 168: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (43).JPG, Target: 0
# Sample 169: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (44).JPG, Target: 0
# Sample 170: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (45).JPG, Target: 0
# Sample 171: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (46).JPG, Target: 0
# Sample 172: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (47).JPG, Target: 0
# Sample 173: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (48).JPG, Target: 0
# Sample 174: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (49).JPG, Target: 0
# Sample 175: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (5).JPG, Target: 0
# Sample 176: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (50).JPG, Target: 0
# Sample 177: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (51).JPG, Target: 0
# Sample 178: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (52).JPG, Target: 0
# Sample 179: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (53).JPG, Target: 0
# Sample 180: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (54).JPG, Target: 0
# Sample 181: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (55).JPG, Target: 0
# Sample 182: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (56).JPG, Target: 0
# Sample 183: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (57).JPG, Target: 0
# Sample 184: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (58).JPG, Target: 0
# Sample 185: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (59).JPG, Target: 0
# Sample 186: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (6).JPG, Target: 0
# Sample 187: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (60).JPG, Target: 0
# Sample 188: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (61).JPG, Target: 0
# Sample 189: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (62).JPG, Target: 0
# Sample 190: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (63).JPG, Target: 0
# Sample 191: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (64).JPG, Target: 0
# Sample 192: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (65).JPG, Target: 0
# Sample 193: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (66).JPG, Target: 0
# Sample 194: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (67).JPG, Target: 0
# Sample 195: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (68).JPG, Target: 0
# Sample 196: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (69).JPG, Target: 0
# Sample 197: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (7).JPG, Target: 0
# Sample 198: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (70).JPG, Target: 0
# Sample 199: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (71).JPG, Target: 0
# Sample 200: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (72).JPG, Target: 0
# Sample 201: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (73).JPG, Target: 0
# Sample 202: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (74).JPG, Target: 0
# Sample 203: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (75).JPG, Target: 0
# Sample 204: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (76).JPG, Target: 0
# Sample 205: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (77).JPG, Target: 0
# Sample 206: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (78).JPG, Target: 0
# Sample 207: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (79).JPG, Target: 0
# Sample 208: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (8).JPG, Target: 0
# Sample 209: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (80).JPG, Target: 0
# Sample 210: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (81).JPG, Target: 0
# Sample 211: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (82).JPG, Target: 0
# Sample 212: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (83).JPG, Target: 0
# Sample 213: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (84).JPG, Target: 0
# Sample 214: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (85).JPG, Target: 0
# Sample 215: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (86).JPG, Target: 0
# Sample 216: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (87).JPG, Target: 0
# Sample 217: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (88).JPG, Target: 0
# Sample 218: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (89).JPG, Target: 0
# Sample 219: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (9).JPG, Target: 0
# Sample 220: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (90).JPG, Target: 0
# Sample 221: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (91).JPG, Target: 0
# Sample 222: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (92).JPG, Target: 0
# Sample 223: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (93).JPG, Target: 0
# Sample 224: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (94).JPG, Target: 0
# Sample 225: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (95).JPG, Target: 0
# Sample 226: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (96).JPG, Target: 0
# Sample 227: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (97).JPG, Target: 0
# Sample 228: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (98).JPG, Target: 0
# Sample 229: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Arjun Leaf (99).JPG, Target: 0
# Sample 230: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Arjun Leaf\Terminalia_arjuna_leaves_01_by_Line1.jpeg, Target: 0
# Sample 231: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (1).jpg, Target: 1
# Sample 232: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (10).jpg, Target: 1
# Sample 233: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (100).jpg, Target: 1
# Sample 234: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (101).jpg, Target: 1
# Sample 235: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (102).jpg, Target: 1
# Sample 236: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (103).jpg, Target: 1
# Sample 237: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (104).jpg, Target: 1
# Sample 238: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (105).jpg, Target: 1
# Sample 239: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (106).jpg, Target: 1
# Sample 240: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (107).jpg, Target: 1
# Sample 241: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (108).jpg, Target: 1
# Sample 242: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (109).jpg, Target: 1
# Sample 243: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (11).jpg, Target: 1
# Sample 244: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (110).jpg, Target: 1
# Sample 245: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (111).jpg, Target: 1
# Sample 246: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (112).jpg, Target: 1
# Sample 247: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (113).jpg, Target: 1
# Sample 248: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (114).jpg, Target: 1
# Sample 249: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (115).jpg, Target: 1
# Sample 250: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (116).jpg, Target: 1
# Sample 251: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (117).jpg, Target: 1
# Sample 252: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (118).jpg, Target: 1
# Sample 253: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (119).jpg, Target: 1
# Sample 254: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (12).jpg, Target: 1
# Sample 255: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (120).jpg, Target: 1
# Sample 256: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (121).jpg, Target: 1
# Sample 257: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (122).jpg, Target: 1
# Sample 258: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (123).jpg, Target: 1
# Sample 259: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (124).jpg, Target: 1
# Sample 260: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (125).jpg, Target: 1
# Sample 261: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (126).jpg, Target: 1
# Sample 262: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (127).jpg, Target: 1
# Sample 263: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (128).jpg, Target: 1
# Sample 264: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (129).jpg, Target: 1
# Sample 265: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (13).jpg, Target: 1
# Sample 266: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (130).jpg, Target: 1
# Sample 267: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (131).jpg, Target: 1
# Sample 268: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (132).jpg, Target: 1
# Sample 269: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (133).jpg, Target: 1
# Sample 270: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (134).jpg, Target: 1
# Sample 271: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (135).jpg, Target: 1
# Sample 272: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (136).jpg, Target: 1
# Sample 273: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (137).jpg, Target: 1
# Sample 274: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (138).jpg, Target: 1
# Sample 275: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (139).jpg, Target: 1
# Sample 276: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (14).jpg, Target: 1
# Sample 277: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (140).jpg, Target: 1
# Sample 278: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (141).jpg, Target: 1
# Sample 279: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (142).jpg, Target: 1
# Sample 280: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (143).jpg, Target: 1
# Sample 281: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (144).jpg, Target: 1
# Sample 282: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (145).jpg, Target: 1
# Sample 283: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (146).jpg, Target: 1
# Sample 284: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (147).jpg, Target: 1
# Sample 285: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (148).jpg, Target: 1
# Sample 286: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (149).jpg, Target: 1
# Sample 287: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (15).jpg, Target: 1
# Sample 288: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (150).jpg, Target: 1
# Sample 289: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (151).jpg, Target: 1
# Sample 290: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (152).jpg, Target: 1
# Sample 291: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (153).jpg, Target: 1
# Sample 292: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (154).jpg, Target: 1
# Sample 293: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (155).jpg, Target: 1
# Sample 294: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (156).jpg, Target: 1
# Sample 295: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (157).jpg, Target: 1
# Sample 296: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (158).jpg, Target: 1
# Sample 297: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (159).jpg, Target: 1
# Sample 298: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (16).jpg, Target: 1
# Sample 299: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (160).jpg, Target: 1
# Sample 300: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (161).jpg, Target: 1
# Sample 301: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (162).jpg, Target: 1
# Sample 302: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (163).jpg, Target: 1
# Sample 303: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (164).jpg, Target: 1
# Sample 304: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (165).jpg, Target: 1
# Sample 305: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (166).jpg, Target: 1
# Sample 306: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (167).jpg, Target: 1
# Sample 307: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (168).jpg, Target: 1
# Sample 308: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (169).jpg, Target: 1
# Sample 309: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (17).jpg, Target: 1
# Sample 310: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (170).jpg, Target: 1
# Sample 311: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (171).jpg, Target: 1
# Sample 312: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (172).jpg, Target: 1
# Sample 313: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (173).jpg, Target: 1
# Sample 314: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (174).jpg, Target: 1
# Sample 315: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (175).jpg, Target: 1
# Sample 316: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (176).jpg, Target: 1
# Sample 317: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (177).jpg, Target: 1
# Sample 318: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (178).jpg, Target: 1
# Sample 319: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (179).jpg, Target: 1
# Sample 320: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (18).jpg, Target: 1
# Sample 321: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (180).jpg, Target: 1
# Sample 322: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (181).jpg, Target: 1
# Sample 323: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (182).jpg, Target: 1
# Sample 324: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (183).jpg, Target: 1
# Sample 325: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (184).jpg, Target: 1
# Sample 326: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (185).jpg, Target: 1
# Sample 327: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (186).jpg, Target: 1
# Sample 328: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (187).jpg, Target: 1
# Sample 329: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (188).jpg, Target: 1
# Sample 330: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (189).jpg, Target: 1
# Sample 331: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (19).jpg, Target: 1
# Sample 332: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (190).jpg, Target: 1
# Sample 333: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (191).jpg, Target: 1
# Sample 334: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (192).jpg, Target: 1
# Sample 335: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (193).jpg, Target: 1
# Sample 336: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (194).jpg, Target: 1
# Sample 337: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (195).jpg, Target: 1
# Sample 338: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (196).jpg, Target: 1
# Sample 339: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (197).jpg, Target: 1
# Sample 340: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (198).jpg, Target: 1
# Sample 341: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (199).jpg, Target: 1
# Sample 342: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (2).jpg, Target: 1
# Sample 343: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (20).jpg, Target: 1
# Sample 344: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (200).jpg, Target: 1
# Sample 345: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (201).jpg, Target: 1
# Sample 346: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (202).jpg, Target: 1
# Sample 347: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (203).jpg, Target: 1
# Sample 348: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (204).jpg, Target: 1
# Sample 349: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (205).jpg, Target: 1
# Sample 350: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (206).jpg, Target: 1
# Sample 351: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (207).jpg, Target: 1
# Sample 352: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (208).jpg, Target: 1
# Sample 353: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (209).jpg, Target: 1
# Sample 354: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (21).jpg, Target: 1
# Sample 355: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (210).jpg, Target: 1
# Sample 356: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (211).jpg, Target: 1
# Sample 357: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (212).jpg, Target: 1
# Sample 358: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (213).jpg, Target: 1
# Sample 359: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (214).jpg, Target: 1
# Sample 360: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (215).jpg, Target: 1
# Sample 361: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (216).jpg, Target: 1
# Sample 362: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (217).jpg, Target: 1
# Sample 363: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (218).jpg, Target: 1
# Sample 364: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (219).jpg, Target: 1
# Sample 365: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (22).jpg, Target: 1
# Sample 366: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (220).jpg, Target: 1
# Sample 367: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (221).jpg, Target: 1
# Sample 368: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (222).jpg, Target: 1
# Sample 369: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (223).jpg, Target: 1
# Sample 370: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (224).jpg, Target: 1
# Sample 371: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (225).jpg, Target: 1
# Sample 372: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (226).jpg, Target: 1
# Sample 373: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (227).jpg, Target: 1
# Sample 374: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (228).jpg, Target: 1
# Sample 375: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (229).jpg, Target: 1
# Sample 376: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (23).jpg, Target: 1
# Sample 377: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (230).jpg, Target: 1
# Sample 378: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (24).jpg, Target: 1
# Sample 379: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (25).jpg, Target: 1
# Sample 380: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (26).jpg, Target: 1
# Sample 381: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (27).jpg, Target: 1
# Sample 382: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (28).jpg, Target: 1
# Sample 383: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (29).jpg, Target: 1
# Sample 384: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (3).jpg, Target: 1
# Sample 385: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (30).jpg, Target: 1
# Sample 386: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (31).jpg, Target: 1
# Sample 387: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (32).jpg, Target: 1
# Sample 388: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (33).jpg, Target: 1
# Sample 389: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (34).jpg, Target: 1
# Sample 390: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (35).jpg, Target: 1
# Sample 391: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (36).jpg, Target: 1
# Sample 392: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (37).jpg, Target: 1
# Sample 393: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (38).jpg, Target: 1
# Sample 394: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (39).jpg, Target: 1
# Sample 395: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (4).jpg, Target: 1
# Sample 396: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (40).jpg, Target: 1
# Sample 397: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (41).jpg, Target: 1
# Sample 398: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (42).jpg, Target: 1
# Sample 399: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (43).jpg, Target: 1
# Sample 400: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (44).jpg, Target: 1
# Sample 401: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (45).jpg, Target: 1
# Sample 402: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (46).jpg, Target: 1
# Sample 403: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (47).jpg, Target: 1
# Sample 404: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (48).jpg, Target: 1
# Sample 405: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (49).jpg, Target: 1
# Sample 406: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (5).jpg, Target: 1
# Sample 407: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (50).jpg, Target: 1
# Sample 408: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (51).jpg, Target: 1
# Sample 409: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (52).jpg, Target: 1
# Sample 410: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (53).jpg, Target: 1
# Sample 411: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (54).jpg, Target: 1
# Sample 412: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (55).jpg, Target: 1
# Sample 413: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (56).jpg, Target: 1
# Sample 414: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (57).jpg, Target: 1
# Sample 415: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (58).jpg, Target: 1
# Sample 416: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (59).jpg, Target: 1
# Sample 417: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (6).jpg, Target: 1
# Sample 418: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (60).jpg, Target: 1
# Sample 419: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (61).jpg, Target: 1
# Sample 420: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (62).jpg, Target: 1
# Sample 421: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (63).jpg, Target: 1
# Sample 422: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (64).jpg, Target: 1
# Sample 423: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (65).jpg, Target: 1
# Sample 424: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (66).jpg, Target: 1
# Sample 425: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (67).jpg, Target: 1
# Sample 426: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (68).jpg, Target: 1
# Sample 427: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (69).jpg, Target: 1
# Sample 428: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (7).jpg, Target: 1
# Sample 429: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (70).jpg, Target: 1
# Sample 430: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (71).jpg, Target: 1
# Sample 431: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (72).jpg, Target: 1
# Sample 432: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (73).jpg, Target: 1
# Sample 433: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (74).jpg, Target: 1
# Sample 434: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (75).jpg, Target: 1
# Sample 435: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (76).jpg, Target: 1
# Sample 436: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (77).jpg, Target: 1
# Sample 437: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (78).jpg, Target: 1
# Sample 438: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (79).jpg, Target: 1
# Sample 439: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (8).jpg, Target: 1
# Sample 440: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (80).jpg, Target: 1
# Sample 441: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (81).jpg, Target: 1
# Sample 442: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (82).jpg, Target: 1
# Sample 443: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (83).jpg, Target: 1
# Sample 444: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (84).jpg, Target: 1
# Sample 445: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (85).jpg, Target: 1
# Sample 446: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (86).jpg, Target: 1
# Sample 447: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (87).jpg, Target: 1
# Sample 448: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (88).jpg, Target: 1
# Sample 449: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (89).jpg, Target: 1
# Sample 450: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (9).jpg, Target: 1
# Sample 451: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (90).jpg, Target: 1
# Sample 452: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (91).jpg, Target: 1
# Sample 453: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (92).jpg, Target: 1
# Sample 454: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (93).jpg, Target: 1
# Sample 455: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (94).jpg, Target: 1
# Sample 456: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (95).jpg, Target: 1
# Sample 457: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (96).jpg, Target: 1
# Sample 458: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (97).jpg, Target: 1
# Sample 459: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (98).jpg, Target: 1
# Sample 460: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Curry leaf\Curry Leaf (99).jpg, Target: 1
# Sample 461: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (1).jpg, Target: 2
# Sample 462: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (10).jpg, Target: 2
# Sample 463: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (100).jpg, Target: 2
# Sample 464: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (101).jpg, Target: 2
# Sample 465: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (102).jpg, Target: 2
# Sample 466: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (103).jpg, Target: 2
# Sample 467: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (104).jpg, Target: 2
# Sample 468: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (105).jpg, Target: 2
# Sample 469: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (106).jpg, Target: 2
# Sample 470: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (107).jpg, Target: 2
# Sample 471: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (108).jpg, Target: 2
# Sample 472: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (109).jpg, Target: 2
# Sample 473: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (11).jpg, Target: 2
# Sample 474: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Marsh Pennywort Leaf\Marsh Pennywort Leaf (110).jpg, Target: 2
# ...
# Sample 1221: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (162).jpg, Target: 5
# Sample 1222: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (163).jpg, Target: 5
# Sample 1223: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (164).jpg, Target: 5
# Sample 1224: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (165).jpg, Target: 5
# Sample 1225: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (166).jpg, Target: 5
# Sample 1226: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (167).jpg, Target: 5
# Sample 1227: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (168).jpg, Target: 5
# Sample 1228: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (169).jpg, Target: 5
# Sample 1229: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (17).jpg, Target: 5
# Sample 1230: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (170).jpg, Target: 5
# Sample 1231: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (171).jpg, Target: 5
# Sample 1232: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (172).jpg, Target: 5
# Sample 1233: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (173).jpg, Target: 5
# Sample 1234: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (174).jpg, Target: 5
# Sample 1235: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (175).jpg, Target: 5
# Sample 1236: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (176).jpg, Target: 5
# Sample 1237: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (177).jpg, Target: 5
# Sample 1238: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (178).jpg, Target: 5
# Sample 1239: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (179).jpg, Target: 5
# Sample 1240: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (18).jpg, Target: 5
# Sample 1241: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (180).jpg, Target: 5
# Sample 1242: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (181).jpg, Target: 5
# Sample 1243: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (182).jpg, Target: 5
# Sample 1244: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (183).jpg, Target: 5
# Sample 1245: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (184).jpg, Target: 5
# Sample 1246: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (185).jpg, Target: 5
# Sample 1247: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (186).jpg, Target: 5
# Sample 1248: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (187).jpg, Target: 5
# Sample 1249: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (188).jpg, Target: 5
# Sample 1250: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (189).jpg, Target: 5
# Sample 1251: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (19).jpg, Target: 5
# Sample 1252: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (190).jpg, Target: 5
# Sample 1253: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (191).jpg, Target: 5
# Sample 1254: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (192).jpg, Target: 5
# Sample 1255: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (193).jpg, Target: 5
# Sample 1256: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (194).jpg, Target: 5
# Sample 1257: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (195).jpg, Target: 5
# Sample 1258: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (196).jpg, Target: 5
# Sample 1259: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (197).jpg, Target: 5
# Sample 1260: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (198).JPG, Target: 5
# Sample 1261: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (199).JPG, Target: 5
# Sample 1262: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (2).jpg, Target: 5
# Sample 1263: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (20).jpg, Target: 5
# Sample 1264: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (200).JPG, Target: 5
# Sample 1265: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (201).JPG, Target: 5
# Sample 1266: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (202).JPG, Target: 5
# Sample 1267: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (203).JPG, Target: 5
# Sample 1268: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (204).JPG, Target: 5
# Sample 1269: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (205).JPG, Target: 5
# Sample 1270: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (206).JPG, Target: 5
# Sample 1271: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (207).JPG, Target: 5
# Sample 1272: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (208).JPG, Target: 5
# Sample 1273: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (209).JPG, Target: 5
# Sample 1274: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (21).jpg, Target: 5
# Sample 1275: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (210).JPG, Target: 5
# Sample 1276: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (211).JPG, Target: 5
# Sample 1277: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (212).JPG, Target: 5
# Sample 1278: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (213).JPG, Target: 5
# Sample 1279: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (214).JPG, Target: 5
# Sample 1280: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (215).JPG, Target: 5
# Sample 1281: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (216).JPG, Target: 5
# Sample 1282: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (217).JPG, Target: 5
# Sample 1283: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (218).JPG, Target: 5
# Sample 1284: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (219).JPG, Target: 5
# Sample 1285: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (22).jpg, Target: 5
# Sample 1286: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (220).JPG, Target: 5
# Sample 1287: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (221).JPG, Target: 5
# Sample 1288: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (222).JPG, Target: 5
# Sample 1289: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (223).JPG, Target: 5
# Sample 1290: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (224).JPG, Target: 5
# Sample 1291: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (225).JPG, Target: 5
# Sample 1292: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (226).JPG, Target: 5
# Sample 1293: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (227).JPG, Target: 5
# Sample 1294: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (228).JPG, Target: 5
# Sample 1295: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (229).JPG, Target: 5
# Sample 1296: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (23).jpg, Target: 5
# Sample 1297: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (230).JPG, Target: 5
# Sample 1298: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (24).jpg, Target: 5
# Sample 1299: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (25).jpg, Target: 5
# Sample 1300: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (26).jpg, Target: 5
# Sample 1301: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (27).jpg, Target: 5
# Sample 1302: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (28).jpg, Target: 5
# Sample 1303: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (29).jpg, Target: 5
# Sample 1304: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (3).jpg, Target: 5
# Sample 1305: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (30).jpg, Target: 5
# Sample 1306: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (31).jpg, Target: 5
# Sample 1307: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (32).jpg, Target: 5
# Sample 1308: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (33).jpg, Target: 5
# Sample 1309: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (34).jpg, Target: 5
# Sample 1310: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (35).jpg, Target: 5
# Sample 1311: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (36).jpg, Target: 5
# Sample 1312: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (37).jpg, Target: 5
# Sample 1313: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (38).jpg, Target: 5
# Sample 1314: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (39).jpg, Target: 5
# Sample 1315: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (4).jpg, Target: 5
# Sample 1316: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (40).jpg, Target: 5
# Sample 1317: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (41).jpg, Target: 5
# Sample 1318: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (42).jpg, Target: 5
# Sample 1319: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (43).jpg, Target: 5
# Sample 1320: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (44).jpg, Target: 5
# Sample 1321: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (45).jpg, Target: 5
# Sample 1322: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (46).jpg, Target: 5
# Sample 1323: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (47).jpg, Target: 5
# Sample 1324: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (48).jpg, Target: 5
# Sample 1325: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (49).jpg, Target: 5
# Sample 1326: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (5).jpg, Target: 5
# Sample 1327: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (50).jpg, Target: 5
# Sample 1328: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (51).jpg, Target: 5
# Sample 1329: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (52).jpg, Target: 5
# Sample 1330: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (53).jpg, Target: 5
# Sample 1331: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (54).jpg, Target: 5
# Sample 1332: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (55).jpg, Target: 5
# Sample 1333: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (56).jpg, Target: 5
# Sample 1334: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (57).jpg, Target: 5
# Sample 1335: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (58).jpg, Target: 5
# Sample 1336: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (59).jpg, Target: 5
# Sample 1337: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (6).jpg, Target: 5
# Sample 1338: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (60).jpg, Target: 5
# Sample 1339: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (61).jpg, Target: 5
# Sample 1340: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (62).jpg, Target: 5
# Sample 1341: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (63).jpg, Target: 5
# Sample 1342: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (64).jpg, Target: 5
# Sample 1343: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (65).jpg, Target: 5
# Sample 1344: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (66).jpg, Target: 5
# Sample 1345: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (67).jpg, Target: 5
# Sample 1346: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (68).jpg, Target: 5
# Sample 1347: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (69).jpg, Target: 5
# Sample 1348: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (7).jpg, Target: 5
# Sample 1349: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (70).jpg, Target: 5
# Sample 1350: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (71).jpg, Target: 5
# Sample 1351: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (72).jpg, Target: 5
# Sample 1352: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (73).jpg, Target: 5
# Sample 1353: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (74).jpg, Target: 5
# Sample 1354: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (75).jpg, Target: 5
# Sample 1355: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (76).jpg, Target: 5
# Sample 1356: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (77).jpg, Target: 5
# Sample 1357: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (78).jpg, Target: 5
# Sample 1358: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (79).jpg, Target: 5
# Sample 1359: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (8).jpg, Target: 5
# Sample 1360: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (80).jpg, Target: 5
# Sample 1361: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (81).jpg, Target: 5
# Sample 1362: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (82).jpg, Target: 5
# Sample 1363: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (83).jpg, Target: 5
# Sample 1364: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (84).jpg, Target: 5
# Sample 1365: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (85).jpg, Target: 5
# Sample 1366: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (86).jpg, Target: 5
# Sample 1367: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (87).jpg, Target: 5
# Sample 1368: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (88).jpg, Target: 5
# Sample 1369: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (89).jpg, Target: 5
# Sample 1370: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (9).jpg, Target: 5
# Sample 1371: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (90).jpg, Target: 5
# Sample 1372: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (91).jpg, Target: 5
# Sample 1373: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (92).jpg, Target: 5
# Sample 1374: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (93).jpg, Target: 5
# Sample 1375: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (94).jpg, Target: 5
# Sample 1376: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (95).jpg, Target: 5
# Sample 1377: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (96).jpg, Target: 5
# Sample 1378: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (97).jpg, Target: 5
# Sample 1379: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (98).jpg, Target: 5
# Sample 1380: Path: ..\Plant-Dataset\New Plant-Dataset\orig\Neem Leaf\Neam Leaf (99).jpg, Target: 5

# %%
torch.save(model.state_dict(), '../Models/herbal-identification-resnet34.pth')

# %%
import jovian

# %%
x = [x]

# Check the content and structure of x
print(x)

# Verify the data type of x[0]
print(type(x[0]))

# Assuming x[0] is a dictionary, access the keys 'val_acc' and 'val_loss'
if isinstance(x[0], dict):
    test_acc = x[0].get('val_acc')
    test_loss = x[0].get('val_loss')
    print("Test Accuracy:", test_acc)
    print("Test Loss:", test_loss)
else:
    print("x[0] is not a dictionary as expected.")
# Out:
# [{'val_loss': 7.952911853790283, 'val_acc': 0.6665003299713135}]
# <class 'dict'>
# Test Accuracy: 0.6665003299713135
# Test Loss: 7.952911853790283

# %%
if isinstance(x[0], dict):
    test_acc = x[0].get('val_acc')
    test_loss = x[0].get('val_loss')
    print("Test Accuracy:", test_acc)
    print("Test Loss:", test_loss)
elif isinstance(x[0], str):
    print("Evaluation result is a string:", x[0])
    # Handle the string result accordingly
else:
    print("Unexpected type for x[0]:", type(x[0]))
# Out:
# Test Accuracy: 0.6665003299713135
# Test Loss: 7.952911853790283

# %%
opt = "Adam"
jovian.reset()
jovian.log_hyperparams(arch=arch, 
                       lrs=lrs, 
                       epochs=epochs,
                       optimizer=opt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 3
#       1 opt = "Adam"
#       2 jovian.reset()
# ----> 3 jovian.log_hyperparams(arch=arch,
#       4                        lrs=lrs,
#       5                        epochs=epochs,
#       6                        optimizer=opt)
#
# NameError: name 'arch' is not defined

# %%
jovian.log_metrics(test_loss=test_loss, test_acc=test_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 # Assuming you have already evaluated your model and stored the results in a variable `evaluation_results`
# ----> 2 test_loss = evaluation_results['val_loss']
#       3 test_acc = evaluation_results['val_acc']
#       5 # Now you can log the metrics
#
# NameError: name 'evaluation_results' is not defined

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Error: Failed to read the Jupyter notebook. Please re-run this cell to try again. If the issue persists, provide the "filename" argument to "jovian.commit" e.g. "jovian.commit(filename='my-notebook.ipynb')"
